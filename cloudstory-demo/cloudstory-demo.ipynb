# %%
import cloudstory as cs

# %%
cs.create_bucket('cloudstory-demo')
# Out:
# 'Created or already exists cloudstory-demo bucket.'

# %%
cs.list_buckets(match='cloud')
# Out:
# Existing buckets containing "cloud" string:
#   cloudstory
#   cloudstory-demo
#   cloudtrail-awslogs-858131396919-isengard-do-not-delete
#   gobuildcloud
#   golearncloud
#   mobilewithcloud-20190331222311-deployment
#   open-data-on-cloud

# %%
cs.list_bucket_contents(bucket='nyc-tlc', match='2018', size_mb=250)
# Out:
# trip data/green_tripdata_2018-01.csv ( 68MB)
# trip data/green_tripdata_2018-02.csv ( 66MB)
# trip data/green_tripdata_2018-03.csv ( 71MB)
# trip data/green_tripdata_2018-04.csv ( 68MB)
# trip data/green_tripdata_2018-05.csv ( 68MB)
# trip data/green_tripdata_2018-06.csv ( 63MB)
# trip data/green_tripdata_2018-07.csv ( 58MB)
# trip data/green_tripdata_2018-08.csv ( 57MB)
# trip data/green_tripdata_2018-09.csv ( 57MB)
# trip data/green_tripdata_2018-10.csv ( 61MB)
# trip data/green_tripdata_2018-11.csv ( 56MB)
# trip data/green_tripdata_2018-12.csv ( 59MB)
# Matched file size is 0.7GB with 12 files
# Bucket nyc-tlc total size is 273.3GB with 251 files

# %%
df = cs.preview_csv_dataset(bucket='nyc-tlc', key='trip data/green_tripdata_2018-02.csv', rows=100)
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2018-02-01 00:39:38   2018-02-01 00:39:41                  N
# 1         2  2018-02-01 00:58:28   2018-02-01 01:05:35                  N
# 2         2  2018-02-01 00:56:05   2018-02-01 01:18:54                  N
# 3         2  2018-02-01 00:12:40   2018-02-01 00:15:50                  N
# 4         2  2018-02-01 00:45:18   2018-02-01 00:51:56                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           5            97            65                1           0.00
# 1           1           256            80                5           1.60
# 2           1            25            95                1           9.60
# 3           1            61            61                1           0.73
# 4           1            65            17                2           1.87
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0         20.0    0.0      0.0        3.00           0.0        NaN
# 1          7.5    0.5      0.5        0.88           0.0        NaN
# 2         28.5    0.5      0.5        5.96           0.0        NaN
# 3          4.5    0.5      0.5        0.00           0.0        NaN
# 4          8.0    0.5      0.5        0.00           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type
# 0                    0.0         23.00             1          2
# 1                    0.3          9.68             1          1
# 2                    0.3         35.76             1          1
# 3                    0.3          5.80             2          1
# 4                    0.3          9.30             2          1

# %%
cs.copy_among_buckets(from_bucket='nyc-tlc', from_key='trip data/green_tripdata_2018-02.csv',
                      to_bucket='cloudstory-demo', to_key='few-trips/trips-2018-02.csv')
# Out:
# File few-trips/trips-2018-02.csv already exists in S3 bucket cloudstory-demo

# %%
df = cs.s3_select(bucket='open-data-analytics-taxi-trips', key='few-trips/trips-2018-02.csv', 
          statement="""
          select passenger_count, payment_type, trip_distance 
          from s3object s 
          where s.passenger_count = '4' 
          limit 100
          """)
# Out:
# Scanned:  1.72MB
# Processed:  1.71MB
# Returned:  0.01MB

# %%
df.head()
# Out:
#    passenger_count  payment_type  trip_distance
# 0                4             1           7.20
# 1                4             1           1.05
# 2                4             1           0.63
# 3                4             2           8.41
# 4                4             2           1.38

# %%
df = cs.s3_select(bucket='nyc-tlc', key='trip data/green_tripdata_2018-02.csv', 
          statement="""
          select passenger_count, payment_type, trip_distance 
          from s3object s 
          where s.passenger_count = '4' 
          limit 100
          """)
# Out:
# Scanned:  1.72MB
# Processed:  1.71MB
# Returned:  0.01MB

# %%
df.head()
# Out:
#    passenger_count  payment_type  trip_distance
# 0                4             1           7.20
# 1                4             1           1.05
# 2                4             1           0.63
# 3                4             2           8.41
# 4                4             2           1.38

# %%
cs.list_bucket_contents(bucket='nyc-tlc', match='2018')
# Out:
# trip data/fhv_tripdata_2018-01.csv (1337MB)
# trip data/fhv_tripdata_2018-02.csv (1307MB)
# trip data/fhv_tripdata_2018-03.csv (1486MB)
# trip data/fhv_tripdata_2018-04.csv (1425MB)
# trip data/fhv_tripdata_2018-05.csv (1459MB)
# trip data/fhv_tripdata_2018-06.csv (1430MB)
# trip data/fhv_tripdata_2018-07.csv (1463MB)
# trip data/fhv_tripdata_2018-08.csv (1498MB)
# trip data/fhv_tripdata_2018-09.csv (1501MB)
# trip data/fhv_tripdata_2018-10.csv (1578MB)
# trip data/fhv_tripdata_2018-11.csv (1550MB)
# trip data/fhv_tripdata_2018-12.csv (1616MB)
# trip data/green_tripdata_2018-01.csv ( 68MB)
# trip data/green_tripdata_2018-02.csv ( 66MB)
# trip data/green_tripdata_2018-03.csv ( 71MB)
# trip data/green_tripdata_2018-04.csv ( 68MB)
# trip data/green_tripdata_2018-05.csv ( 68MB)
# trip data/green_tripdata_2018-06.csv ( 63MB)
# trip data/green_tripdata_2018-07.csv ( 58MB)
# trip data/green_tripdata_2018-08.csv ( 57MB)
# trip data/green_tripdata_2018-09.csv ( 57MB)
# trip data/green_tripdata_2018-10.csv ( 61MB)
# trip data/green_tripdata_2018-11.csv ( 56MB)
# trip data/green_tripdata_2018-12.csv ( 59MB)
# trip data/yellow_tripdata_2018-01.csv (736MB)
# trip data/yellow_tripdata_2018-02.csv (714MB)
# trip data/yellow_tripdata_2018-03.csv (793MB)
# trip data/yellow_tripdata_2018-04.csv (783MB)
# trip data/yellow_tripdata_2018-05.csv (777MB)
# trip data/yellow_tripdata_2018-06.csv (734MB)
# trip data/yellow_tripdata_2018-07.csv (660MB)
# trip data/yellow_tripdata_2018-08.csv (660MB)
# trip data/yellow_tripdata_2018-09.csv (677MB)
# trip data/yellow_tripdata_2018-10.csv (743MB)
# trip data/yellow_tripdata_2018-11.csv (686MB)
# trip data/yellow_tripdata_2018-12.csv (688MB)
# Matched file size is 26.4GB with 36 files
# Bucket nyc-tlc total size is 273.3GB with 251 files

# %%
cs.preview_csv_dataset(bucket='nyc-tlc', key='trip data/yellow_tripdata_2018-06.csv')
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2018-06-01 00:15:40   2018-06-01 00:16:46                1
# 1         1  2018-06-01 00:04:18   2018-06-01 00:09:18                1
# 2         1  2018-06-01 00:14:39   2018-06-01 00:29:46                1
# 3         1  2018-06-01 00:51:25   2018-06-01 00:51:29                3
# 4         1  2018-06-01 00:55:06   2018-06-01 00:55:10                1
# 5         1  2018-06-01 00:09:00   2018-06-01 00:24:01                1
# 6         1  2018-06-01 00:02:33   2018-06-01 00:13:01                2
# 7         1  2018-06-01 00:13:23   2018-06-01 00:16:52                1
# 8         1  2018-06-01 00:24:29   2018-06-01 01:08:43                1
# 9         2  2018-06-01 00:17:01   2018-06-01 00:23:16                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.00           1                  N           145           145
# 1           1.00           1                  N           230           161
# 2           3.30           1                  N           100           263
# 3           0.00           1                  N           145           145
# 4           0.00           1                  N           145           145
# 5           2.00           1                  N           161           234
# 6           1.50           1                  N           163           233
# 7           0.70           1                  N           186           246
# 8           5.70           1                  N           230           179
# 9           0.85           1                  N           179           223
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2          3.0    0.5      0.5        0.00             0
# 1             1          5.5    0.5      0.5        1.35             0
# 2             2         13.0    0.5      0.5        0.00             0
# 3             2          2.5    0.5      0.5        0.00             0
# 4             2          2.5    0.5      0.5        0.00             0
# 5             1         11.5    0.5      0.5        2.55             0
# 6             1          8.5    0.5      0.5        1.95             0
# 7             1          5.0    0.5      0.5        1.85             0
# 8             2         22.0    0.5      0.5        0.00             0
# 9             2          6.0    0.5      0.5        0.00             0
#
#    improvement_surcharge  total_amount
# 0                    0.3          4.30
# 1                    0.3          8.15
# 2                    0.3         14.30
# 3                    0.3          3.80
# 4                    0.3          3.80
# 5                    0.3         15.35
# 6                    0.3         11.75
# 7                    0.3          8.15
# 8                    0.3         23.30
# 9                    0.3          7.30

# %%
cs.copy_among_buckets(from_bucket='nyc-tlc', from_key='trip data/yellow_tripdata_2018-06.csv',
                      to_bucket='cloudstory-demo', to_key='many-trips/trips-2018-06.csv')
# Out:
# File many-trips/trips-2018-06.csv already exists in S3 bucket cloudstory-demo

# %%
cs.list_bucket_contents(bucket='cloudstory-demo', match='trips/trips')
# Out:
# few-trips/trips-2018-02.csv ( 66MB)
# many-trips/trips-2018-06.csv (734MB)
# Matched file size is 0.8GB with 2 files
# Bucket cloudstory-demo total size is 0.8GB with 6 files

# %%
cs.list_glue_databases()
# Out:
# default
# odoc
# sampledb
# taxicatalog

# %%
cs.list_glue_tables('taxicatalog', verbose=False)
# Out:
# **Table: many_trips**
# Location: s3://open-data-analytics-taxi-trips/many-trips/
# Created by: AWS-Crawler
# **Table: many_trips_well_formed**
# Location: s3://open-data-analytics-taxi-trips/many-trips-well-formed
# Created by: manav

# %%
output_bucket = 'cloudstory-demo'
folder = 'queries'
query = 'SELECT * FROM "taxicatalog"."many_trips_well_formed" TABLESAMPLE BERNOULLI(100) LIMIT 1000;'

df = cs.athena_query(query, output_bucket, folder)
df.head()
# Out:
#    vendor  passengers  distance  rate  pick_location  drop_location  \
# 0       1           1      0.90     1            229            161
# 1       1           1      1.80     1            142            236
# 2       1           1      1.50     1            236            237
# 3       2           1      1.86     1            231            234
# 4       2           1      0.98     1             79            144
#
#    payment_type  fare  extra_fare  tax   tip  toll  surcharge  total_fare  \
# 0             1  10.0         0.0  0.5  2.70   0.0        0.3       13.50
# 1             1  10.5         0.0  0.5  2.80   0.0        0.3       14.10
# 2             1   7.0         0.0  0.5  1.55   0.0        0.3        9.35
# 3             2  11.0         0.0  0.5  0.00   0.0        0.3       11.80
# 4             1   6.5         0.0  0.5  1.00   0.0        0.3        8.30
#
#              pick_when            drop_when
# 0  2018-06-19 09:10:56  2018-06-19 09:25:58
# 1  2018-06-19 09:37:58  2018-06-19 09:50:57
# 2  2018-06-19 09:54:30  2018-06-19 10:01:38
# 3  2018-06-19 09:08:03  2018-06-19 09:23:05
# 4  2018-06-19 09:42:31  2018-06-19 09:49:20

# %%
df = df.drop(columns=['surcharge'])

# %%
corr = df.corr()
corr
# Out:
#                  vendor  passengers  distance      rate  pick_location  \
# vendor         1.000000    0.217379  0.066786  0.009710      -0.030975
# passengers     0.217379    1.000000  0.024276  0.033657      -0.009088
# distance       0.066786    0.024276  1.000000  0.293480      -0.034460
# rate           0.009710    0.033657  0.293480  1.000000       0.053725
# pick_location -0.030975   -0.009088 -0.034460  0.053725       1.000000
# drop_location -0.017031   -0.014795 -0.020598  0.044314       0.101859
# payment_type  -0.057138   -0.001576 -0.076609  0.025018      -0.003984
# fare           0.069351    0.017819  0.888252  0.461693      -0.011733
# extra_fare          NaN         NaN       NaN       NaN            NaN
# tax            0.019491   -0.033466 -0.092010 -0.595304      -0.038345
# tip            0.056852    0.006688  0.651208  0.296839       0.009760
# toll           0.002501   -0.006065  0.731975  0.421222      -0.011116
# total_fare     0.064944    0.014307  0.893147  0.459089      -0.007675
#
#                drop_location  payment_type      fare  extra_fare       tax  \
# vendor             -0.017031     -0.057138  0.069351         NaN  0.019491
# passengers         -0.014795     -0.001576  0.017819         NaN -0.033466
# distance           -0.020598     -0.076609  0.888252         NaN -0.092010
# rate                0.044314      0.025018  0.461693         NaN -0.595304
# pick_location       0.101859     -0.003984 -0.011733         NaN -0.038345
# drop_location       1.000000     -0.042072 -0.033498         NaN -0.036314
# payment_type       -0.042072      1.000000 -0.090229         NaN -0.108793
# fare               -0.033498     -0.090229  1.000000         NaN -0.120350
# extra_fare               NaN           NaN       NaN         NaN       NaN
# tax                -0.036314     -0.108793 -0.120350         NaN  1.000000
# tip                 0.000967     -0.476851  0.706551         NaN -0.093974
# toll                0.047540     -0.053797  0.701522         NaN -0.279059
# total_fare         -0.019813     -0.165495  0.985466         NaN -0.139070
#
#                     tip      toll  total_fare
# vendor         0.056852  0.002501    0.064944
# passengers     0.006688 -0.006065    0.014307
# distance       0.651208  0.731975    0.893147
# rate           0.296839  0.421222    0.459089
# pick_location  0.009760 -0.011116   -0.007675
# drop_location  0.000967  0.047540   -0.019813
# payment_type  -0.476851 -0.053797   -0.165495
# fare           0.706551  0.701522    0.985466
# extra_fare          NaN       NaN         NaN
# tax           -0.093974 -0.279059   -0.139070
# tip            1.000000  0.584669    0.800431
# toll           0.584669  1.000000    0.768321
# total_fare     0.800431  0.768321    1.000000

# %%
cs.heatmap(corr)

# %%
image_bucket = 'open-data-analytics-taxi-trips'
cs.show_image(image_bucket, 'images/traffic-in-manhattan.jpg', 1024)
# Out:
# <img src="https://s3.amazonaws.com/open-data-analytics-taxi-trips/images/traffic-in-manhattan.jpg" width="1024"/>

# %%
cs.image_labels(image_bucket, 'images/traffic-in-manhattan.jpg')
# Out:
# Vehicle (100%)
# Car (100%)
# Transportation (100%)
# Automobile (100%)
# Human (99%)
# Person (99%)
# Truck (98%)
# Machine (96%)
# Wheel (96%)
# Footwear (87%)
# Clothing (87%)
# Apparel (87%)
# Shoe (87%)
# Road (75%)
# Traffic Jam (73%)
# Town (73%)
# City (73%)
# Building (73%)
# Urban (73%)
# Metropolis (73%)
# Taxi (71%)
# Cab (71%)
# Light (68%)
# Traffic Light (68%)
# Neighborhood (62%)
# People (62%)
# Pedestrian (59%)

# %%
cs.image_label_count(image_bucket, 'images/traffic-in-manhattan.jpg', 'Car')
# Out:
# Found Car 9 times.

# %%
cs.image_label_count(image_bucket, 'images/traffic-in-manhattan.jpg', 'Truck')
# Out:
# Found Truck 4 times.

# %%
cs.image_label_count(image_bucket, 'images/traffic-in-manhattan.jpg', 'Person')
# Out:
# Found Person 8 times.

# %%
cs.show_image(image_bucket, 'images/nyc-taxi-signs.jpeg', 1024)
# Out:
# <img src="https://s3.amazonaws.com/open-data-analytics-taxi-trips/images/nyc-taxi-signs.jpeg" width="1024"/>

# %%
cs.image_text(image_bucket, 'images/nyc-taxi-signs.jpeg', sort_column='Top', parents=False)
# Out:
#     Confidence DetectedText  Id  ParentId  Type     Width    Height      Left  \
# 14   91.874588          WAY  15       1.0  WORD  0.028470  0.019385  0.599400
# 15   83.133957         6ASW  14       1.0  WORD  0.034089  0.018404  0.570143
# 17   94.518997        HAN'S  17       2.0  WORD  0.070971  0.032111  0.388597
# 16   99.643578         DELI  16       2.0  WORD  0.080892  0.041151  0.281320
# 18   90.439896            &  18       3.0  WORD  0.027007  0.044044  0.364591
# 19   99.936119      GROCERY  19       3.0  WORD  0.150999  0.042149  0.399850
# 20   87.067184          iGi  20       4.0  WORD  0.026257  0.023023  0.595649
# 21   95.180290        SHOES  21       5.0  WORD  0.041695  0.019078  0.621906
# 22   91.584435   X29CONEYSL  23       5.0  WORD  0.108448  0.038509  0.887472
# 23   90.353638          x29  24       5.0  WORD  0.038896  0.033245  0.888972
# 24   96.308746          647  22       5.0  WORD  0.018755  0.016016  0.747937
# 25   97.540222     BROADWAY  25       6.0  WORD  0.055210  0.018034  0.768192
# 26   89.723869          NEW  27       7.0  WORD  0.033758  0.019019  0.587397
# 27   92.452881         YORK  28       7.0  WORD  0.035273  0.020034  0.618905
# 29   92.044113         CITY  29       7.0  WORD  0.027007  0.016016  0.655664
# 28   95.421768         food  26       7.0  WORD  0.033758  0.024024  0.555889
# 33   92.179512         WINE  33       8.0  WORD  0.044261  0.022035  0.592648
# 31   87.556816         LIon  31       8.0  WORD  0.041260  0.030030  0.336084
# 32   90.025581         KING  32       8.0  WORD  0.045022  0.033042  0.377344
# 34   96.632484         FOOD  35       8.0  WORD  0.043522  0.021034  0.645911
# 30   98.496071          THE  30       8.0  WORD  0.031508  0.023023  0.303826
# 36   91.229187  FESTIVALFOS  34       8.0  WORD  0.089278  0.021021  0.596399
# 35   71.623650          EME  36       9.0  WORD  0.029257  0.027027  0.450113
# 37   88.608627     Oct.9-12  37       9.0  WORD  0.036773  0.016016  0.553638
# 38   91.010559         SALE  38       9.0  WORD  0.023788  0.018158  0.735934
# 39   80.209984           02  39      10.0  WORD  0.024027  0.021034  0.077269
# 40   85.682373      9214'',  40      11.0  WORD  0.112688  0.028068  0.762191
# 41   97.959709         TAXI  42      12.0  WORD  0.104583  0.052101  0.488372
# 42   96.415970          NYC  41      12.0  WORD  0.066138  0.036067  0.414104
#
#          Top
# 14  0.109109
# 15  0.126126
# 17  0.187187
# 16  0.201201
# 18  0.212212
# 19  0.217217
# 20  0.265265
# 21  0.269269
# 22  0.279279
# 23  0.282282
# 24  0.293293
# 25  0.295295
# 26  0.379379
# 27  0.382382
# 29  0.389389
# 28  0.392392
# 33  0.398398
# 31  0.400400
# 32  0.400400
# 34  0.402402
# 30  0.403403
# 36  0.419419
# 35  0.426426
# 37  0.437437
# 38  0.452452
# 39  0.488488
# 40  0.600601
# 41  0.716717
# 42  0.736737

# %%
cs.show_image(image_bucket, 'images/world-leaders.jpg', 1024)
# Out:
# <img src="https://s3.amazonaws.com/open-data-analytics-taxi-trips/images/world-leaders.jpg" width="1024"/>

# %%
cs.detect_celebs(image_bucket, 'images/world-leaders.jpg', sort_column='Left')
# Out:
#           Id  MatchConfidence                            Name  \
# 3    4Ev8IX1            100.0                      Chulabhorn
# 5     3J795K            100.0                  Manmohan Singh
# 25    f0JR5e             90.0               Mahinda Rajapaksa
# 30   3n7tl2O             88.0                   Killah Priest
# 12  2gC0Tc0e            100.0                Rosen Plevneliev
# 19  3LR2lb6j             56.0                  Jerry Harrison
# 1     4hD40O            100.0                Thomas Boni Yayi
# 22    2F5LV4             63.0                       Irwansyah
# 8   3hk2qj5G             98.0  Cristina Fernández de Kirchner
# 13  2sN1oC8s            100.0            Jorge Carlos Fonseca
# 9   3Ns4kC2b            100.0                Sebastián Piñera
# 15  1qy7Yt8D            100.0       Gurbanguly Berdimuhamedow
# 4   1eA7EJ2W             63.0                    Salim Durani
# 20  2vr4uV3M             95.0     Albert II, Prince of Monaco
# 29   4pv6OP8             90.0                      Nick Clegg
# 7    pL8KD9X            100.0            Denis Sassou Nguesso
# 0     46JZ2c             97.0                     Ban Ki-moon
# 27  2yG8Fe4x             79.0                         Mem Fox
# 18   2nk8Bd0             58.0               Ali Bongo Ondimba
# 2   2aE2DV3K            100.0        Susilo Bambang Yudhoyono
# 17    3m4lC0             82.0                  Uhuru Kenyatta
# 28    K8hL4i             67.0                  Erkki Tuomioja
# 26  2KJ7KM8e            100.0               Isatou Njie-Saidy
# 14    aU4fU4            100.0                Laura Chinchilla
# 16  2DM2OT1F             91.0                     Alpha Condé
# 11   4eh5t9f             99.0          Helle Thorning-Schmidt
# 21   Em8cA8q             70.0                  Ollanta Humala
# 24  4FT4On6a             94.0                   Mariano Rajoy
# 23   1oa5Af1             73.0                James Van Praagh
# 10    47mP82             82.0                      János Áder
# 6    16BU2ey             99.0             José Manuel Barroso
#
#                              Urls     Width    Height      Left       Top
# 3                              []  0.020202  0.038973  0.015152  0.424905
# 5                              []  0.018687  0.035171  0.131313  0.420152
# 25                             []  0.016162  0.030418  0.145960  0.319392
# 30  [www.imdb.com/name/nm0697334]  0.014646  0.027567  0.162121  0.290875
# 12                             []  0.018182  0.034221  0.179293  0.367871
# 19                             []  0.017172  0.032319  0.227273  0.330798
# 1                              []  0.021717  0.040875  0.236364  0.399240
# 22  [www.imdb.com/name/nm2679097]  0.016667  0.031369  0.274747  0.340304
# 8   [www.imdb.com/name/nm3231417]  0.018687  0.035171  0.278283  0.414449
# 13                             []  0.018182  0.034221  0.280808  0.370722
# 9                              []  0.018687  0.035171  0.318687  0.374525
# 15                             []  0.018182  0.034221  0.334848  0.317490
# 4                              []  0.019192  0.036122  0.418687  0.331749
# 20                             []  0.017172  0.032319  0.463636  0.332700
# 29  [www.imdb.com/name/nm2200958]  0.015152  0.028517  0.465152  0.255703
# 7                              []  0.018687  0.035171  0.472727  0.368821
# 0   [www.imdb.com/name/nm2559634]  0.022727  0.042776  0.526768  0.402091
# 27                             []  0.015152  0.028517  0.607071  0.351711
# 18                             []  0.017172  0.032319  0.612121  0.381179
# 2   [www.imdb.com/name/nm2670444]  0.020707  0.038973  0.626263  0.403042
# 17  [www.imdb.com/name/nm6045979]  0.017172  0.032319  0.650505  0.343156
# 28                             []  0.015152  0.028517  0.657071  0.280418
# 26                             []  0.015657  0.029468  0.666162  0.396388
# 14                             []  0.018182  0.034221  0.679798  0.429658
# 16                             []  0.017677  0.033270  0.708586  0.369772
# 11  [www.imdb.com/name/nm1525284]  0.018182  0.034221  0.723232  0.399240
# 21                             []  0.017172  0.032319  0.766667  0.355513
# 24  [www.imdb.com/name/nm1775577]  0.016162  0.030418  0.786869  0.282319
# 23  [www.imdb.com/name/nm1070530]  0.016667  0.031369  0.806061  0.378327
# 10                             []  0.018182  0.034221  0.848485  0.365970
# 6                              []  0.018687  0.035171  0.960606  0.408745

# %%
traffic_update = """
It is snowing and windy today in New York. The temperature is 50 degrees Fahrenheit. 
The traffic is slow 10 mph with several jams along the I-86.
"""

# %%
cs.comprehend_syntax(traffic_update)
# Out:
#     BeginOffset  EndOffset         Text  TokenId    Tag     Score
# 0             1          3           It        1   PRON  0.999971
# 1             4          6           is        2   VERB  0.557677
# 2             7         14      snowing        3    ADJ  0.687805
# 3            15         18          and        4   CONJ  0.999998
# 4            19         24        windy        5    ADJ  0.994336
# 5            25         30        today        6   NOUN  0.999980
# 6            31         33           in        7    ADP  0.999924
# 7            34         37          New        8  PROPN  0.999351
# 8            38         42         York        9  PROPN  0.998399
# 9            42         43            .       10  PUNCT  0.999998
# 10           44         47          The       11    DET  0.999979
# 11           48         59  temperature       12   NOUN  0.999760
# 12           60         62           is       13   VERB  0.998011
# 13           63         65           50       14    NUM  0.999716
# 14           66         73      degrees       15   NOUN  0.999700
# 15           74         84   Fahrenheit       16  PROPN  0.950743
# 16           84         85            .       17  PUNCT  0.999994
# 17           87         90          The       18    DET  0.999975
# 18           91         98      traffic       19   NOUN  0.999450
# 19           99        101           is       20   VERB  0.965014
# 20          102        106         slow       21    ADJ  0.815718
# 21          107        109           10       22    NUM  0.999991
# 22          110        113          mph       23   NOUN  0.988531
# 23          114        118         with       24    ADP  0.973397
# 24          119        126      several       25    ADJ  0.999647
# 25          127        131         jams       26   NOUN  0.999936
# 26          132        137        along       27    ADP  0.997718
# 27          138        141          the       28    DET  0.999960
# 28          142        143            I       29  PROPN  0.745183
# 29          143        144            -       30  PUNCT  0.999858
# 30          144        146           86       31  PROPN  0.684016
# 31          146        147            .       32  PUNCT  0.999985

# %%
cs.comprehend_entities(traffic_update)
# Out:
#    BeginOffset  EndOffset     Score                   Text      Type
# 0           25         30  0.839589                  today      DATE
# 1           34         42  0.998423               New York  LOCATION
# 2           63         84  0.984396  50 degrees Fahrenheit  QUANTITY
# 3          107        113  0.992498                 10 mph  QUANTITY
# 4          142        146  0.990993                   I-86  LOCATION

# %%
cs.comprehend_phrases(traffic_update)
# Out:
#    BeginOffset  EndOffset     Score             Text
# 0           25         30  0.988285            today
# 1           34         42  0.997397         New York
# 2           44         59  0.999752  The temperature
# 3           63         73  0.789843       50 degrees
# 4           87         98  0.999843      The traffic
# 5          107        113  0.924737           10 mph
# 6          119        131  0.998428     several jams
# 7          138        146  0.997108         the I-86

# %%
cs.comprehend_sentiment(traffic_update)
# Out:
# {'Positive': 0.04090394824743271,
#  'Negative': 0.3745909333229065,
#  'Neutral': 0.5641733407974243,
#  'Mixed': 0.020331736654043198}

# %%
bucket='cloudstory'
key='notebooks-media/alexa-for-business-people.mp4'

cs.show_video(bucket, key)
# Out:
#     <div align="middle">
#         <video width="100%" controls>
#         <source src="https://s3.amazonaws.com/cloudstory/notebooks-media/alexa-for-business-people.mp4" type="video/mp4">
#         </video>
#     </div>

# %%
jobId = cs.video_labels_job(bucket, key)
jobId
# Out:
# 'd3c19ca3e77238ebc2d1a56115a4a72069aecd9afe678c661a43880b7af78ea0'

# %%
df = cs.video_labels_result(jobId)
df.head(10)
# Out:
# 'In Progress...'
# 'Getting Labels...'
# 'Video Duration (ms): 11345'
# 'FrameRate: 23'
# 'Succeeded in detecting 1256 labels.'
#    Timestamp        LabelName  Score  Instances  ParentsCount        Parents
# 0          0          Apparel  66.54          0             0
# 1          0         Audience  50.53          0             2  Crowd, Person
# 2          0         Building  60.53          0             0
# 3          0         Clothing  66.54          0             0
# 4          0             Coat  66.54          0             1       Clothing
# 5          0         Computer  82.03          0             1    Electronics
# 6          0  Conference Room  86.87          0             2  Indoors, Room
# 7          0            Crowd  54.35          0             1         Person
# 8          0      Electronics  82.03          0             0
# 9          0        Furniture  76.07          0             0

# %%
text = cs.video_labels_text(df)
text[500:1000]
# Out:
# 'nce Room Crowd Electronics Furniture Hardware Human Indoors Interview Meeting Room Mouse Office Office Building Overcoat People Person Room Sitting Speech Suit Table Apparel Audience Building Clothing Coat Computer Conference Room Crowd Electronics Furniture Hardware Human Indoors Interview Meeting Room Mouse Office Office Building Overcoat People Person Room Sitting Speech Suit Table Apparel Audience Building Clothing Coat Computer Conference Room Crowd Electronics Furniture Hardware Human Indo'

# %%
cs.video_labels_wordcloud(text)

# %%
cs.video_labels_search(df, 'LabelName', 'Person')
# Out:
#       Timestamp LabelName  Score  Instances  ParentsCount Parents
# 20            0    Person  99.76          4             0
# 46          166    Person  99.76          4             0
# 72          375    Person  99.76          4             0
# 98          583    Person  99.76          4             0
# 125         792    Person  99.77          4             0
# 151         959    Person  99.77          4             0
# 176        1167    Person  99.77          4             0
# 198        1376    Person  99.73          4             0
# 215        1584    Person  99.69          4             0
# 228        1793    Person  99.65          2             0
# 242        1960    Person  99.63          2             0
# 259        2168    Person  99.59          2             0
# 275        2377    Person  99.54          2             0
# 291        2585    Person  99.48          2             0
# 307        2794    Person  99.40          2             0
# 326        2961    Person  99.31          2             0
# 344        3169    Person  99.23          2             0
# 361        3378    Person  99.20          2             0
# 375        3586    Person  80.42          2             0
# 385        3795    Person  60.30          2             0
# 409        4379    Person  60.73          4             0
# 423        4587    Person  80.97          5             0
# 445        4796    Person  99.86          6             0
# 473        4963    Person  99.87          6             0
# 500        5171    Person  99.87          6             0
# 523        5380    Person  99.85          6             0
# 542        5588    Person  99.84          6             0
# 562        5797    Person  99.81          4             0
# 585        5964    Person  99.79          4             0
# 610        6172    Person  99.77          4             0
# 636        6381    Person  99.77          4             0
# 661        6589    Person  99.77          4             0
# 684        6798    Person  99.76          4             0
# 703        6965    Person  99.76          4             0
# 724        7173    Person  99.57          4             0
# 748        7382    Person  99.41          4             0
# 772        7590    Person  98.96          3             0
# 798        7799    Person  98.73          3             0
# 824        7966    Person  98.56          3             0
# 851        8174    Person  98.60          3             0
# 878        8383    Person  98.63          3             0
# 905        8591    Person  98.92          3             0
# 932        8758    Person  99.08          3             0
# 959        8967    Person  99.16          3             0
# 985        9175    Person  99.27          3             0
# 1011       9384    Person  99.35          3             0
# 1037       9592    Person  99.51          3             0
# 1060       9759    Person  99.58          3             0
# 1089       9968    Person  99.70         12             0
# 1115      10176    Person  99.79         12             0
# 1143      10385    Person  99.87         10             0
# 1171      10593    Person  99.85          6             0
# 1195      10760    Person  99.82          7             0
# 1220      10969    Person  99.81          6             0
# 1246      11177    Person  99.79          6             0

# %%
cs.video_labels_search(df, 'Parents', 'Computer')
# Out:
#       Timestamp LabelName  Score  Instances  ParentsCount  \
# 15            0     Mouse  82.03          1             3
# 41          166     Mouse  83.93          1             3
# 67          375     Mouse  85.22          1             3
# 93          583     Mouse  87.57          1             3
# 119         792     Mouse  89.41          1             3
# 123         792        Pc  50.10          0             2
# 146         959     Mouse  89.70          1             3
# 172        1167     Mouse  90.15          1             3
# 195        1376     Mouse  73.25          1             3
# 214        1584     Mouse  55.04          1             3
# 560        5797        Pc  50.37          0             2
# 580        5964     Mouse  67.05          1             3
# 584        5964        Pc  51.90          0             2
# 605        6172     Mouse  83.16          1             3
# 609        6172        Pc  53.31          0             2
# 631        6381     Mouse  84.25          1             3
# 635        6381        Pc  53.09          0             2
# 657        6589     Mouse  84.47          1             3
# 660        6589        Pc  53.37          0             2
# 680        6798     Mouse  83.63          1             3
# 683        6798        Pc  53.33          0             2
# 699        6965     Mouse  82.93          1             3
# 702        6965        Pc  53.48          0             2
# 720        7173     Mouse  66.84          1             3
# 723        7173        Pc  61.54          0             2
# 744        7382    Laptop  57.33          0             3
# 747        7382        Pc  70.09          0             2
# 768        7590    Laptop  65.76          1             3
# 771        7590        Pc  79.20          0             2
# 793        7799    Laptop  73.28          1             3
# 797        7799        Pc  87.87          0             2
# 819        7966    Laptop  81.46          1             3
# 823        7966        Pc  96.47          0             2
# 846        8174    Laptop  81.36          1             3
# 850        8174        Pc  97.02          0             2
# 873        8383    Laptop  82.76          1             3
# 877        8383        Pc  97.62          0             2
# 900        8591    Laptop  83.73          1             3
# 904        8591        Pc  97.65          0             2
# 927        8758    Laptop  85.55          1             3
# 931        8758        Pc  97.95          0             2
# 954        8967    Laptop  85.10          1             3
# 958        8967        Pc  97.64          0             2
# 980        9175    Laptop  84.59          1             3
# 984        9175        Pc  97.41          0             2
# 1006       9384    Laptop  83.80          1             3
# 1010       9384        Pc  97.35          0             2
# 1032       9592    Laptop  67.26          1             3
# 1036       9592        Pc  85.71          0             2
# 1059       9759        Pc  72.86          0             2
# 1088       9968        Pc  60.99          0             2
#
#                               Parents
# 15    Computer, Hardware, Electronics
# 41    Computer, Electronics, Hardware
# 67    Electronics, Hardware, Computer
# 93    Hardware, Electronics, Computer
# 119   Hardware, Computer, Electronics
# 123             Computer, Electronics
# 146   Hardware, Computer, Electronics
# 172   Computer, Hardware, Electronics
# 195   Electronics, Computer, Hardware
# 214   Computer, Hardware, Electronics
# 560             Electronics, Computer
# 580   Electronics, Hardware, Computer
# 584             Electronics, Computer
# 605   Hardware, Computer, Electronics
# 609             Computer, Electronics
# 631   Hardware, Computer, Electronics
# 635             Computer, Electronics
# 657   Computer, Electronics, Hardware
# 660             Computer, Electronics
# 680   Hardware, Electronics, Computer
# 683             Electronics, Computer
# 699   Computer, Hardware, Electronics
# 702             Computer, Electronics
# 720   Hardware, Computer, Electronics
# 723             Computer, Electronics
# 744         Computer, Electronics, Pc
# 747             Computer, Electronics
# 768         Pc, Computer, Electronics
# 771             Computer, Electronics
# 793         Electronics, Pc, Computer
# 797             Electronics, Computer
# 819         Electronics, Computer, Pc
# 823             Electronics, Computer
# 846         Pc, Computer, Electronics
# 850             Computer, Electronics
# 873         Pc, Computer, Electronics
# 877             Computer, Electronics
# 900         Electronics, Pc, Computer
# 904             Electronics, Computer
# 927         Computer, Electronics, Pc
# 931             Computer, Electronics
# 954         Electronics, Pc, Computer
# 958             Electronics, Computer
# 980         Computer, Pc, Electronics
# 984             Computer, Electronics
# 1006        Computer, Electronics, Pc
# 1010            Computer, Electronics
# 1032        Electronics, Computer, Pc
# 1036            Electronics, Computer
# 1059            Electronics, Computer
# 1088            Electronics, Computer

# %%
cs.video_label_stats(df, 'Person')
# Out:
# Displaying stats on number of instances for label "Person"
#           Timestamp      Score  Instances  ParentsCount
# count     55.000000  55.000000  55.000000          55.0
# mean    5633.072727  97.434545   4.145455           0.0
# std     3366.954899   8.072887   2.197795           0.0
# min        0.000000  60.300000   2.000000           0.0
# 25%     2689.500000  99.250000   3.000000           0.0
# 50%     5797.000000  99.690000   4.000000           0.0
# 75%     8487.000000  99.770000   4.000000           0.0
# max    11177.000000  99.870000  12.000000           0.0
